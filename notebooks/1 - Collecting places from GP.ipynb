#             print(geometry.Polygon([tuple(l) for l in j['coordinates'][0]]))
            list_polygons.append(geometry.Polygon([tuple(l) for l in j['coordinates'][0]]))
        shape = list_polygons[0] if len(list_polygons) == 1 else geometry.MultiPolygon(list_polygons)
        poly_wkt.append(shape)
        poly.append(wkb.dumps(shape, hex=True, srid=4326))
    except:
        poly_wkt.append('')
        poly.append('')

# %%
gpd.GeoSeries(poly_wkt[0]).to_file('data/bounds Krasnodar.shp')

# %%
gdf = gpd.read_file('grid x1000.geojson')

# %%
gdf = gdf.to_crs(epsg = 4326)
gdf.head()
gdf.shape
# Out:
# (600, 6)

# %%
gdf = gdf[['id', 'geometry']]

# %%
gdf.geometry = gdf.geometry.explode(index_parts=False)

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Сбор данных из GP

# %%
# !pip install googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.5.3-py3-none-any.whl size=38479 sha256=f9673d4fd0e1552141c556d454d22d9818b619e739b79cf96f5b884a233c4cb8
#   Stored in directory: c:\users\yupes\appdata\local\pip\cache\wheels\45\3a\bd\ac73c8f5202c55a700dcdaddd30207b57825bb8a22925b9074
# Successfully built googlemaps
# ...

# %%
import googlemaps
import time
from IPython.core.display import display, HTML
from IPython.display import IFrame
import re
from multiprocessing.dummy import Pool
from multiprocessing import cpu_count, freeze_support
from functools import partial

# %%
#логер
def log_progress(sequence, every=None, size=None):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display
    
    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = size / 200     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)
    
    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{index} / ?'.format(index=index)
                else:
                    progress.value = index
                    label.value = u'{index} / {size}'.format(
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = str(index or '?')

# %%
key='AIzaSyAUPnbU7F5csfO8tqgt6xP_1zEKDoRx8GA'

# %%
gmaps = googlemaps.Client(key = key)

# %%
def get_places(lat, lng, radius, keywords = ''):
    places = []
    next_page_token = None
    while next_page_token != '':
#         result = gmaps.places_nearby(location = (lat, lng), radius=radius, type = keywords, page_token=next_page_token)
        result = gmaps.places_nearby(location = (lat, lng), radius=radius, page_token=next_page_token)
        next_page_token = result['next_page_token'] if 'next_page_token' in result else ''
        places.extend(result['results'])
        time.sleep(2)
    return places

# %%
gdf.geometry[0].x
# Out:
# 38.79473247268239

# %%
places = []
def load_point(geometries):
    for point in log_progress(geometries,1):
        try:
            places.append(get_places(point.y, point.x, 710, ''))
    #         for keyword in keywords:
    #             places.append(get_places(point['ycoord'], point['xcoord'], 710, keywords = keyword))
        except Exception as e:
            print(e)

# %%
datalist=gdf.geometry
places = []

if __name__== "__main__":
    freeze_support()
    pool = Pool()

    # max number of parallel process
    ITERATION_COUNT = cpu_count()-1

    count_per_iteration = len(datalist) / float(ITERATION_COUNT)

    for i in range(0, ITERATION_COUNT):
        list_start = int(count_per_iteration * i)
        list_end = int(count_per_iteration * (i+1))
        pool.apply_async(load_point, [datalist[list_start:list_end]])

# %%
placess = []
[placess.extend(p) for p in places]
places_df = pd.DataFrame(placess)

# %%
places_df.drop_duplicates('reference', inplace = True)

# %%
places_df['lat'] = places_df.geometry.apply(lambda g: g['location']['lat'])
places_df['lon'] = places_df.geometry.apply(lambda g: g['location']['lng'])
places_df['url'] = places_df.place_id.apply(lambda u: "https://www.google.com/maps/place/?q=place_id:" + u)

# %%
places_df.geometry = [geometry.Point(r['lon'], r['lat']) for i, r in places_df.iterrows()]

# %%
gpd.GeoDataFrame(places_df).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Количество собранных мест

# %%
places_df.shape[0]
# Out:
# 15190

# %%
gpd.GeoDataFrame(places_df).to_csv('data/raw_data.csv', index = False)

# %% [markdown]
# # Категории мест

# %%
places_df.sort_values('user_ratings_total', ascending = False)
# Out:
#                         geometry  \
# 3045   POINT (39.03178 45.04164)
# 3046   POINT (39.02919 45.04449)
# 1392   POINT (38.99397 45.09639)
# 16011  POINT (39.01224 45.08723)
# 11675  POINT (39.12662 45.03775)
# ...                          ...
# 24223  POINT (39.02056 45.10814)
# 24224  POINT (39.02056 45.10814)
# 24226  POINT (39.02526 45.11119)
# 24228  POINT (39.02453 45.11101)
# 24230  POINT (39.02456 45.11110)
#
#                                                     icon  \
# 3045   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3046   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1392   https://maps.gstatic.com/mapfiles/place_api/ic...
# 16011  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11675  https://maps.gstatic.com/mapfiles/place_api/ic...
# ...                                                  ...
# 24223  https://maps.gstatic.com/mapfiles/place_api/ic...
# 24224  https://maps.gstatic.com/mapfiles/place_api/ic...
# ...

# %%
places_df.types.explode().value_counts()
# Out:
# point_of_interest      15170
# establishment          15170
# store                   4010
# health                  1051
# food                    1000
#                        ...
# neighborhood               2
# movie_theater              2
# sublocality_level_1        1
# embassy                    1
# light_rail_station         1
# Name: types, Length: 99, dtype: int64

# %% [markdown]
# Локальности

# %%
places_df.loc[~places_df.types.astype(str).str.contains('point_of_interest')]['types'].astype(str).value_counts()
# Out:
# ['locality', 'political']                              13
# ['sublocality_level_2', 'sublocality', 'political']     4
# ['neighborhood', 'political']                           2
# ['sublocality_level_1', 'sublocality', 'political']     1
# Name: types, dtype: int64

# %% [markdown]
# Туристическая привлекательность

# %%
places_df.loc[places_df.types.astype(str).str.contains('tourist_attraction')]['types'].astype(str).value_counts()
# Out:
# ['park', 'tourist_attraction', 'point_of_interest', 'establishment']                4
# ['tourist_attraction', 'point_of_interest', 'establishment']                        3
# ['zoo', 'tourist_attraction', 'point_of_interest', 'establishment']                 2
# ['amusement_park', 'tourist_attraction', 'point_of_interest', 'establishment']      2
# ['museum', 'tourist_attraction', 'point_of_interest', 'establishment']              2
# ['tourist_attraction', 'place_of_worship', 'point_of_interest', 'establishment']    1
# Name: types, dtype: int64
